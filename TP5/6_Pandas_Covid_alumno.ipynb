# %% [markdown]
# <a href="https://colab.research.google.com/github/cesar-s-s/Bootcam-MindHub/blob/main/TP5/6_Pandas_Covid_alumno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller de Pandas - COVID

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧼 Importar Pandas

# %%
import pandas as pd

# %% [markdown]
# 🧼 Leer el .csv "Covid19Argentina"

# %%
covid = pd.read_csv("Covid19Argentina.csv")

# %%
covid
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
# 1       2019-07-13          CABA              2            COMUNA 02
# 2       2020-02-11          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 4       2020-02-20          CABA              2            COMUNA 04
# ...            ...           ...            ...                  ...
# 17519   2020-08-27         Jujuy             38             Palpalá
# 17520   2020-08-27          CABA              2            COMUNA 04
# 17521   2020-08-27  Buenos Aires              6     Florencio Varela
# 17522   2020-08-27          CABA              2            COMUNA 09
# 17523   2020-08-29          CABA              2            COMUNA 04
#
#        District_Code               Locality  Locality_Code Financing  \
# 0                 21  SAN SALVADOR DE JUJUY             60    Public
# 1                  2               RECOLETA             10    Public
# 2                  4       PARQUE PATRICIOS             10    Public
# 3                 56           BAHIA BLANCA             10   Private
# 4                  4       PARQUE PATRICIOS             10    Public
# ...              ...                    ...            ...       ...
# 17519             42                PALPALA             40   Private
# 17520              4       PARQUE PATRICIOS             10   Private
# 17521            274         VILLA VATTEONE             10    Public
# 17522              9                LINIERS             10    Public
# 17523              4       PARQUE PATRICIOS             10    Public
#
#                     Type  Total_Tests  Positive_Cases
# 0             Provincial            1             0.0
# 1      Public University            1             0.0
# 2               National            2             0.0
# 3                Private            1             0.0
# 4               National            1             0.0
# ...                  ...          ...             ...
# 17519            Private            3             2.0
# 17520            Private            8             0.0
# 17521         Provincial           23            11.0
# 17522          Municipal            2             1.0
# 17523           National            1             0.0
#
# [17524 rows x 11 columns]

# %% [markdown]
# 🧼 Imprimir los primeros 5 registros del dataframe

# %%
covid.head(5)
# Out:
#   Testing_Date      Province  Province_Code             District  \
# 0   2008-08-13         Jujuy             38  Dr. Manuel Belgrano
# 1   2019-07-13          CABA              2            COMUNA 02
# 2   2020-02-11          CABA              2            COMUNA 04
# 3   2020-02-20  Buenos Aires              6         Bahía Blanca
# 4   2020-02-20          CABA              2            COMUNA 04
#
#    District_Code               Locality  Locality_Code Financing  \
# 0             21  SAN SALVADOR DE JUJUY             60    Public
# 1              2               RECOLETA             10    Public
# 2              4       PARQUE PATRICIOS             10    Public
# 3             56           BAHIA BLANCA             10   Private
# 4              4       PARQUE PATRICIOS             10    Public
#
#                 Type  Total_Tests  Positive_Cases
# 0         Provincial            1             0.0
# 1  Public University            1             0.0
# 2           National            2             0.0
# 3            Private            1             0.0
# 4           National            1             0.0

# %% [markdown]
# 🧼 Imprimir la cantidad de filas y columnas del df

# %%
covid.shape
# Out:
# (17524, 11)

# %% [markdown]
# 🧼 Utiliza un metodo perteneciente a los df para imprimir las columnas, la cantidad de no-nulos de cada una y el tipo de dato

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17524 entries, 0 to 17523
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Testing_Date    17524 non-null  object
#  1   Province        17522 non-null  object
#  2   Province_Code   17524 non-null  int64
#  3   District        17524 non-null  object
#  4   District_Code   17524 non-null  int64
#  5   Locality        17524 non-null  object
#  6   Locality_Code   17524 non-null  int64
#  7   Financing       17524 non-null  object
#  8   Type            17524 non-null  object
#  9   Total_Tests     17524 non-null  int64
#  10  Positive_Cases  17522 non-null  float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# 🧼 Utiliza un metodo perteneciente a los df para imprimir informacion estadistica del df

# %%
covid.describe()
# Out:
#        Province_Code  District_Code  Locality_Code   Total_Tests  \
# count   17524.000000   17524.000000   17524.000000  17524.000000
# mean       24.615328     158.231340      53.242981     71.154873
# std        28.522829     230.802172      95.104505    148.029044
# min         2.000000       0.000000       0.000000      1.000000
# 25%         2.000000      12.000000      10.000000      4.000000
# 50%         6.000000      35.000000      10.000000     21.000000
# 75%        50.000000     260.000000      50.000000     68.000000
# max        99.000000     882.000000     560.000000   1738.000000
#
#        Positive_Cases
# count    17522.000000
# mean        23.326618
# std         64.207189
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%         18.000000
# max        943.000000

# %% [markdown]
# ⚠️¿Hay nulos en el df?⚠️
#
# El tratamiento de los nulos es "todo un tema", pero generalmente podemos decir que hay 4 posibles vias de accion:
#
# 🦠Eliminar los registros que tienen nulos
#
# 🦠Eliminar las columnas que tengan nulos (aconsejable si hay una columna con muchisimos nulos)
#
# 🦠Rellenar los nulos con medidas estadisticas: promedio, mediana y moda
#
# 🦠Rellenar los nulos con un algoritmo de aprendizaje automatico

# %% [markdown]
# 🧼 Imprimir solo las filas que contengan nulo en alguna columna

# %%
covid.isna().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17519    False
# 17520    False
# 17521    False
# 17522    False
# 17523    False
# Length: 17524, dtype: bool

# %%
covid.loc[covid.isna().any(axis=1),:]
# Out:
#    Testing_Date Province  Province_Code      District  District_Code  \
# 9    2020-03-02      NaN              2     COMUNA 04              4
# 12   2020-03-05     CABA              2     COMUNA 04              4
# 20   2020-03-11     CABA              2     COMUNA 04              4
# 60   2020-03-21      NaN              6  Bahía Blanca             56
#
#             Locality  Locality_Code Financing      Type  Total_Tests  \
# 9   PARQUE PATRICIOS             10    Public  National            5
# 12  PARQUE PATRICIOS             10    Public  National            7
# 20  PARQUE PATRICIOS             10    Public  National           34
# 60      BAHIA BLANCA             10   Private   Private            2
#
#     Positive_Cases
# 9              0.0
# 12             NaN
# 20             NaN
# 60             0.0

# %%
covid[covid.isnull().any(axis=1)]
# Out:
#    Testing_Date Province  Province_Code      District  District_Code  \
# 9    2020-03-02      NaN              2     COMUNA 04              4
# 12   2020-03-05     CABA              2     COMUNA 04              4
# 20   2020-03-11     CABA              2     COMUNA 04              4
# 60   2020-03-21      NaN              6  Bahía Blanca             56
#
#             Locality  Locality_Code Financing      Type  Total_Tests  \
# 9   PARQUE PATRICIOS             10    Public  National            5
# 12  PARQUE PATRICIOS             10    Public  National            7
# 20  PARQUE PATRICIOS             10    Public  National           34
# 60      BAHIA BLANCA             10   Private   Private            2
#
#     Positive_Cases
# 9              0.0
# 12             NaN
# 20             NaN
# 60             0.0

# %% [markdown]
# 🧼 Eliminar los registros que tienen nulos

# %%
covid.dropna(inplace=True)

# %%
covid.shape
# Out:
# (17520, 11)

# %%
limpio = covid.dropna()

# %% [markdown]
# ⚠️A partir de ahora trabajaremos con el df sin nulos⚠️

# %% [markdown]
# 🧼 Ordenar el df en orden descendente tomando como referencia Testing_Date

# %%
covid.sort_values('Testing_Date', ascending=False)
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 17523   2020-08-29          CABA              2            COMUNA 04
# 17402   2020-08-27          CABA              2            COMUNA 02
# 17420   2020-08-27       Neuquén             58          Confluencia
# 17419   2020-08-27  Buenos Aires              6   General San Martín
# 17418   2020-08-27  Buenos Aires              6           San Miguel
# ...            ...           ...            ...                  ...
# 4       2020-02-20          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 2       2020-02-11          CABA              2            COMUNA 04
# 1       2019-07-13          CABA              2            COMUNA 02
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
#
#        District_Code               Locality  Locality_Code Financing  \
# 17523              4       PARQUE PATRICIOS             10    Public
# 17402              2               RECOLETA             10   Private
# 17420             35                NEUQUEN             70   Private
# 17419            371     GENERAL SAN MARTÍN             10    Public
# 17418            760            BELLA VISTA             10    Public
# ...              ...                    ...            ...       ...
# 4                  4       PARQUE PATRICIOS             10    Public
# 3                 56           BAHIA BLANCA             10   Private
# 2                  4       PARQUE PATRICIOS             10    Public
# 1                  2               RECOLETA             10    Public
# 0                 21  SAN SALVADOR DE JUJUY             60    Public
#
#                     Type  Total_Tests  Positive_Cases
# 17523           National            1             0.0
# 17402            Private          716           290.0
# 17420            Private           35            21.0
# 17419         Provincial           25            10.0
# 17418          Municipal          114            72.0
# ...                  ...          ...             ...
# 4               National            1             0.0
# 3                Private            1             0.0
# 2               National            2             0.0
# 1      Public University            1             0.0
# 0             Provincial            1             0.0
#
# [17524 rows x 11 columns]

# %% [markdown]
# 🧼 Ordenar el df en orden ascendente tomando como referencia Testing_Date

# %%
covid.sort_values('Testing_Date', ascending=False)
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 17523   2020-08-29          CABA              2            COMUNA 04
# 17402   2020-08-27          CABA              2            COMUNA 02
# 17420   2020-08-27       Neuquén             58          Confluencia
# 17419   2020-08-27  Buenos Aires              6   General San Martín
# 17418   2020-08-27  Buenos Aires              6           San Miguel
# ...            ...           ...            ...                  ...
# 4       2020-02-20          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 2       2020-02-11          CABA              2            COMUNA 04
# 1       2019-07-13          CABA              2            COMUNA 02
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
#
#        District_Code               Locality  Locality_Code Financing  \
# 17523              4       PARQUE PATRICIOS             10    Public
# 17402              2               RECOLETA             10   Private
# 17420             35                NEUQUEN             70   Private
# 17419            371     GENERAL SAN MARTÍN             10    Public
# 17418            760            BELLA VISTA             10    Public
# ...              ...                    ...            ...       ...
# 4                  4       PARQUE PATRICIOS             10    Public
# 3                 56           BAHIA BLANCA             10   Private
# 2                  4       PARQUE PATRICIOS             10    Public
# 1                  2               RECOLETA             10    Public
# 0                 21  SAN SALVADOR DE JUJUY             60    Public
#
#                     Type  Total_Tests  Positive_Cases
# 17523           National            1             0.0
# 17402            Private          716           290.0
# 17420            Private           35            21.0
# 17419         Provincial           25            10.0
# 17418          Municipal          114            72.0
# ...                  ...          ...             ...
# 4               National            1             0.0
# 3                Private            1             0.0
# 2               National            2             0.0
# 1      Public University            1             0.0
# 0             Provincial            1             0.0
#
# [17524 rows x 11 columns]

# %%
covid.sort_values('Testing_Date', ascending=False)
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 17523   2020-08-29          CABA              2            COMUNA 04
# 17402   2020-08-27          CABA              2            COMUNA 02
# 17420   2020-08-27       Neuquén             58          Confluencia
# 17419   2020-08-27  Buenos Aires              6   General San Martín
# 17418   2020-08-27  Buenos Aires              6           San Miguel
# ...            ...           ...            ...                  ...
# 4       2020-02-20          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 2       2020-02-11          CABA              2            COMUNA 04
# 1       2019-07-13          CABA              2            COMUNA 02
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
#
#        District_Code               Locality  Locality_Code Financing  \
# 17523              4       PARQUE PATRICIOS             10    Public
# 17402              2               RECOLETA             10   Private
# 17420             35                NEUQUEN             70   Private
# 17419            371     GENERAL SAN MARTÍN             10    Public
# 17418            760            BELLA VISTA             10    Public
# ...              ...                    ...            ...       ...
# 4                  4       PARQUE PATRICIOS             10    Public
# 3                 56           BAHIA BLANCA             10   Private
# 2                  4       PARQUE PATRICIOS             10    Public
# 1                  2               RECOLETA             10    Public
# 0                 21  SAN SALVADOR DE JUJUY             60    Public
#
#                     Type  Total_Tests  Positive_Cases
# 17523           National            1             0.0
# 17402            Private          716           290.0
# 17420            Private           35            21.0
# 17419         Provincial           25            10.0
# 17418          Municipal          114            72.0
# ...                  ...          ...             ...
# 4               National            1             0.0
# 3                Private            1             0.0
# 2               National            2             0.0
# 1      Public University            1             0.0
# 0             Provincial            1             0.0
#
# [17524 rows x 11 columns]

# %% [markdown]
# ⚠️¿Podes ver alguna incongruencia en los datos?⚠️

# %% [markdown]
# 🧼Eliminar los registros cuyo Testing_Date sea anterior al primer registro de covid en China: 17 de Noviembre de 2019

# %%
covid = covid.loc[(covid['Testing_Date']> '2019-11-17'),]

# %%
covid
# Out:
#       Testing_Date             Province  Province_Code          District  \
# 2       2020-02-11                 CABA              2         COMUNA 04
# 3       2020-02-20         Buenos Aires              6      Bahía Blanca
# 4       2020-02-20                 CABA              2         COMUNA 04
# 5       2020-02-25  Santiago del Estero             86      Capital City
# 6       2020-02-27  Santiago del Estero             86      Capital City
# ...            ...                  ...            ...               ...
# 17519   2020-08-27                Jujuy             38          Palpalá
# 17520   2020-08-27                 CABA              2         COMUNA 04
# 17521   2020-08-27         Buenos Aires              6  Florencio Varela
# 17522   2020-08-27                 CABA              2         COMUNA 09
# 17523   2020-08-29                 CABA              2         COMUNA 04
#
#        District_Code             Locality  Locality_Code Financing  \
# 2                  4     PARQUE PATRICIOS             10    Public
# 3                 56         BAHIA BLANCA             10   Private
# 4                  4     PARQUE PATRICIOS             10    Public
# 5                 49  SANTIAGO DEL ESTERO            110    Public
# 6                 49  SANTIAGO DEL ESTERO            110    Public
# ...              ...                  ...            ...       ...
# 17519             42              PALPALA             40   Private
# 17520              4     PARQUE PATRICIOS             10   Private
# 17521            274       VILLA VATTEONE             10    Public
# 17522              9              LINIERS             10    Public
# 17523              4     PARQUE PATRICIOS             10    Public
#
#              Type  Total_Tests  Positive_Cases
# 2        National            2             0.0
# 3         Private            1             0.0
# 4        National            1             0.0
# 5      Provincial            1             0.0
# 6      Provincial            1             0.0
# ...           ...          ...             ...
# 17519     Private            3             2.0
# 17520     Private            8             0.0
# 17521  Provincial           23            11.0
# 17522   Municipal            2             1.0
# 17523    National            1             0.0
#
# [17522 rows x 11 columns]

# %% [markdown]
# 🧼Resetear el indice del df:

# %%
covid.reset_index(drop = True, inplace = True)
covid
# Out:
#       Testing_Date             Province  Province_Code          District  \
# 0       2020-02-11                 CABA              2         COMUNA 04
# 1       2020-02-20         Buenos Aires              6      Bahía Blanca
# 2       2020-02-20                 CABA              2         COMUNA 04
# 3       2020-02-25  Santiago del Estero             86      Capital City
# 4       2020-02-27  Santiago del Estero             86      Capital City
# ...            ...                  ...            ...               ...
# 17517   2020-08-27                Jujuy             38          Palpalá
# 17518   2020-08-27                 CABA              2         COMUNA 04
# 17519   2020-08-27         Buenos Aires              6  Florencio Varela
# 17520   2020-08-27                 CABA              2         COMUNA 09
# 17521   2020-08-29                 CABA              2         COMUNA 04
#
#        District_Code             Locality  Locality_Code Financing  \
# 0                  4     PARQUE PATRICIOS             10    Public
# 1                 56         BAHIA BLANCA             10   Private
# 2                  4     PARQUE PATRICIOS             10    Public
# 3                 49  SANTIAGO DEL ESTERO            110    Public
# 4                 49  SANTIAGO DEL ESTERO            110    Public
# ...              ...                  ...            ...       ...
# 17517             42              PALPALA             40   Private
# 17518              4     PARQUE PATRICIOS             10   Private
# 17519            274       VILLA VATTEONE             10    Public
# 17520              9              LINIERS             10    Public
# 17521              4     PARQUE PATRICIOS             10    Public
#
#              Type  Total_Tests  Positive_Cases
# 0        National            2             0.0
# 1         Private            1             0.0
# 2        National            1             0.0
# 3      Provincial            1             0.0
# 4      Provincial            1             0.0
# ...           ...          ...             ...
# 17517     Private            3             2.0
# 17518     Private            8             0.0
# 17519  Provincial           23            11.0
# 17520   Municipal            2             1.0
# 17521    National            1             0.0
#
# [17522 rows x 11 columns]

# %% [markdown]
# 🧼Analizar la distribucion de registros en las diferentes provincias

# %%
covid.loc[:,'Province'].value_counts()
# Out:
# Buenos Aires           5664
# CABA                   4529
# Río Negro               991
# Mendoza                 818
# Santa Fe                726
# Chubut                  487
# Córdoba                 424
# Chaco                   406
# Santa Cruz              339
# Neuquén                 319
# Jujuy                   305
# Salta                   292
# Tucumán                 259
# La Rioja                253
# Entre Ríos              245
# La Pampa                214
# Tierra del Fuego        179
# Corrientes              172
# San Juan                165
# Santiago del Estero     158
# Misiones                148
# Formosa                 142
# San Luis                135
# Catamarca               123
# NOT SPECIFIED            27
# Name: Province, dtype: int64

# %%
import seaborn as sns
sns.displot(data = covid, y = 'Province')

# %% [markdown]
# 🧼Calcular la cantidad de valores unicos en la columna Province

# %%
covid.loc[:,'Province'].nunique()
# Out:
# 25

# %% [markdown]
# ⚠️Vemos que la cantidad de valores unicos coincide con las 24 jurisdicciones: 23 provincias y Capital Federal + Una categoria "NOT SPECIFIED"

# %% [markdown]
# 🦠Analizar la distribucion de registros por Financing y Type

# %%
covid.loc[:,"Financing"].value_counts()
# Out:
# Public     11293
# Private     6229
# Name: Financing, dtype: int64

# %%
covid.loc[:,"Type"].value_counts()
# Out:
# Provincial            6730
# Private               5825
# Municipal             2622
# National              1070
# Public University      438
# Armed forces           426
# Social Security        244
# Mixed                  154
# Prison Service           7
# Private University       3
# Mutual                   3
# Name: Type, dtype: int64

# %%
covid.loc[:, 'Province'].mode()
# Out:
# 0    Buenos Aires
# Name: Province, dtype: object

# %% [markdown]
# 🦠Agregar una nueva columna llamada "Alerta" la cual tendra 1 si la cantidad de casos positivos supera la mediana, en caso contrario un 0

# %%
import numpy as np

# %%
mediana = covid.loc[:,'Positive_Cases'].median()

# %%
covid['Alerta']= np.where(covid["Positive_Cases"]> mediana, 1 , 0)

# %%
covid
# Out:
#       Testing_Date             Province  Province_Code          District  \
# 0       2020-02-11                 CABA              2         COMUNA 04
# 1       2020-02-20         Buenos Aires              6      Bahía Blanca
# 2       2020-02-20                 CABA              2         COMUNA 04
# 3       2020-02-25  Santiago del Estero             86      Capital City
# 4       2020-02-27  Santiago del Estero             86      Capital City
# ...            ...                  ...            ...               ...
# 17513   2020-08-27                Jujuy             38          Palpalá
# 17514   2020-08-27                 CABA              2         COMUNA 04
# 17515   2020-08-27         Buenos Aires              6  Florencio Varela
# 17516   2020-08-27                 CABA              2         COMUNA 09
# 17517   2020-08-29                 CABA              2         COMUNA 04
#
#        District_Code             Locality  Locality_Code Financing  \
# 0                  4     PARQUE PATRICIOS             10    Public
# 1                 56         BAHIA BLANCA             10   Private
# 2                  4     PARQUE PATRICIOS             10    Public
# 3                 49  SANTIAGO DEL ESTERO            110    Public
# 4                 49  SANTIAGO DEL ESTERO            110    Public
# ...              ...                  ...            ...       ...
# 17513             42              PALPALA             40   Private
# 17514              4     PARQUE PATRICIOS             10   Private
# 17515            274       VILLA VATTEONE             10    Public
# 17516              9              LINIERS             10    Public
# 17517              4     PARQUE PATRICIOS             10    Public
#
#              Type  Total_Tests  Positive_Cases  Alerta
# 0        National            2             0.0       0
# 1         Private            1             0.0       0
# 2        National            1             0.0       0
# 3      Provincial            1             0.0       0
# 4      Provincial            1             0.0       0
# ...           ...          ...             ...     ...
# 17513     Private            3             2.0       0
# 17514     Private            8             0.0       0
# 17515  Provincial           23            11.0       1
# 17516   Municipal            2             1.0       0
# 17517    National            1             0.0       0
#
# [17518 rows x 12 columns]

# %% [markdown]
# 🦠 Hay una forma mucho mas facil:

# %% [markdown]
# 😵 **Ejercicios** 😵

# %% [markdown]
# ✔️1.Crear una nueva columna llamada Positividad la cual sea igual a la division de los casos positivos entre el total de tests

# %%
covid['Positividad'] = covid['Positive_Cases'] / covid['Total_Tests']

# %%
covid
# Out:
#       Testing_Date             Province  Province_Code          District  \
# 0       2020-02-11                 CABA              2         COMUNA 04
# 1       2020-02-20         Buenos Aires              6      Bahía Blanca
# 2       2020-02-20                 CABA              2         COMUNA 04
# 3       2020-02-25  Santiago del Estero             86      Capital City
# 4       2020-02-27  Santiago del Estero             86      Capital City
# ...            ...                  ...            ...               ...
# 17513   2020-08-27                Jujuy             38          Palpalá
# 17514   2020-08-27                 CABA              2         COMUNA 04
# 17515   2020-08-27         Buenos Aires              6  Florencio Varela
# 17516   2020-08-27                 CABA              2         COMUNA 09
# 17517   2020-08-29                 CABA              2         COMUNA 04
#
#        District_Code             Locality  Locality_Code Financing  \
# 0                  4     PARQUE PATRICIOS             10    Public
# 1                 56         BAHIA BLANCA             10   Private
# 2                  4     PARQUE PATRICIOS             10    Public
# 3                 49  SANTIAGO DEL ESTERO            110    Public
# 4                 49  SANTIAGO DEL ESTERO            110    Public
# ...              ...                  ...            ...       ...
# 17513             42              PALPALA             40   Private
# 17514              4     PARQUE PATRICIOS             10   Private
# 17515            274       VILLA VATTEONE             10    Public
# 17516              9              LINIERS             10    Public
# 17517              4     PARQUE PATRICIOS             10    Public
#
#              Type  Total_Tests  Positive_Cases  Alerta  Positividad
# 0        National            2             0.0       0     0.000000
# 1         Private            1             0.0       0     0.000000
# 2        National            1             0.0       0     0.000000
# 3      Provincial            1             0.0       0     0.000000
# 4      Provincial            1             0.0       0     0.000000
# ...           ...          ...             ...     ...          ...
# 17513     Private            3             2.0       0     0.666667
# 17514     Private            8             0.0       0     0.000000
# 17515  Provincial           23            11.0       1     0.478261
# 17516   Municipal            2             1.0       0     0.500000
# 17517    National            1             0.0       0     0.000000
#
# [17518 rows x 13 columns]

# %% [markdown]
# ✔️2.Obtener un dataframe con solo registros de CABA y tengan localidad en parque patricios

# %%
covid.loc[covid['Locality'] == 'Parque Patricios',:]
# Out:
# Empty DataFrame
# Columns: [Testing_Date, Province, Province_Code, District, District_Code, Locality, Locality_Code, Financing, Type, Total_Tests, Positive_Cases, Alerta, Positividad]
# Index: []

# %% [markdown]
# ✔️3.Obtener un dataframe con solo registros de Buenos Aires que sean de tipo privado y tengan casos positivos superiores a 10, finalmente ordena de forma descendente

# %%
covid.loc[(covid['Province'] == 'Buenos Aires') & (covid['Type'] == 'Private') & (covid['Positive_Cases'] > 10)].sort_values('Positive_Cases', ascending = False)
# Out:
#       Testing_Date      Province  Province_Code      District  District_Code  \
# 11324   2020-07-24  Buenos Aires              6  Bahía Blanca             56
# 17084   2020-08-25  Buenos Aires              6      La Plata            441
# 13932   2020-08-08  Buenos Aires              6  Bahía Blanca             56
# 14928   2020-08-14  Buenos Aires              6  Bahía Blanca             56
# 15882   2020-08-19  Buenos Aires              6      La Plata            441
# ...            ...           ...            ...           ...            ...
# 9262    2020-07-09  Buenos Aires              6       Quilmes            658
# 12173   2020-07-29  Buenos Aires              6    San Isidro            756
# 9358    2020-07-10  Buenos Aires              6    La Matanza            427
# 14310   2020-08-10  Buenos Aires              6    San Miguel            760
# 14116   2020-08-09  Buenos Aires              6    Hurlingham            408
#
#             Locality  Locality_Code Financing     Type  Total_Tests  \
# 11324   BAHIA BLANCA             10   Private  Private          376
# 17084       LA PLATA             30   Private  Private          272
# 13932   BAHIA BLANCA             10   Private  Private          384
# 14928   BAHIA BLANCA             10   Private  Private          245
# 15882       LA PLATA             30   Private  Private          255
# ...              ...            ...       ...      ...          ...
# 9262   QUILMES OESTE             10   Private  Private           31
# 12173       MARTINEZ             10   Private  Private          100
# 9358     RAMOS MEJIA             10   Private  Private           25
# 14310     SAN MIGUEL             10   Private  Private           27
# 14116     HURLINGHAM             10   Private  Private           12
#
#        Positive_Cases  Alerta  Positividad
# 11324           130.0       1     0.345745
# 17084           121.0       1     0.444853
# 13932           111.0       1     0.289062
# 14928           109.0       1     0.444898
# 15882           108.0       1     0.423529
# ...               ...     ...          ...
# 9262             11.0       1     0.354839
# 12173            11.0       1     0.110000
# 9358             11.0       1     0.440000
# 14310            11.0       1     0.407407
# 14116            11.0       1     0.916667
#
# [410 rows x 13 columns]

# %% [markdown]
# ✔️4.Obtener un dataframe con registros que pertenezcan a Buenos Aires o tengan mas de 10 test realizados

# %%
# df.loc[filas, columas]


# 1. Selecciona la sfilas de una columna específica

# df.loc[:,'nombre']


# 2. Selecciona varias columnas específicas

# df.loc[:, ['Nombre', 'Edad','Sexo']]


# 3. Selecciona un rupo de rango de filas y columanas

# df.loc[1:5, 'Nombre':'Edad']

# %%
# Datos de la Columna

covid['Province'].unique()
# Out:
# array(['Jujuy', 'CABA', 'Buenos Aires', 'Santiago del Estero', nan,
#        'Córdoba', 'Santa Fe', 'Neuquén', 'Chaco', 'Tierra del Fuego',
#        'San Luis', 'Corrientes', 'Río Negro', 'Mendoza', 'Formosa',
#        'Misiones', 'Entre Ríos', 'Catamarca', 'Tucumán', 'Salta',
#        'La Pampa', 'La Rioja', 'Chubut', 'Santa Cruz', 'San Juan',
#        'NOT SPECIFIED'], dtype=object)

# %%
(covid['Province']=='Buenos Aires') & (covid['Total_Tests'] >10)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17519    False
# 17520    False
# 17521     True
# 17522    False
# 17523    False
# Length: 17524, dtype: bool

# %%
covid.loc[covid['Province'].str.contains('San'),]
# Out:
#       Testing_Date             Province  Province_Code      District  \
# 3       2020-02-25  Santiago del Estero             86  Capital City
# 4       2020-02-27  Santiago del Estero             86  Capital City
# 11      2020-03-08  Santiago del Estero             86  Capital City
# 16      2020-03-11             Santa Fe             82       Rosario
# 32      2020-03-18             Santa Fe             82       Rosario
# ...            ...                  ...            ...           ...
# 17440   2020-08-27             Santa Fe             82       Caseros
# 17441   2020-08-27             Santa Fe             82       Rosario
# 17447   2020-08-27             Santa Fe             82       Caseros
# 17480   2020-08-27  Santiago del Estero             86  Capital City
# 17503   2020-08-27             San Luis             74    La Capital
#
#        District_Code             Locality  Locality_Code Financing  \
# 3                 49  SANTIAGO DEL ESTERO            110    Public
# 4                 49  SANTIAGO DEL ESTERO            110    Public
# 11                49  SANTIAGO DEL ESTERO            110    Public
# 16                84              ROSARIO            270   Private
# 32                84              ROSARIO            270    Public
# ...              ...                  ...            ...       ...
# 17440             14              CASILDA             50    Public
# 17441             84              ROSARIO            270   Private
# 17447             14              CASILDA             50   Private
# 17480             49  SANTIAGO DEL ESTERO            110    Public
# 17503             56             SAN LUIS            150    Public
#
#              Type  Total_Tests  Positive_Cases  Alerta  Positividad
# 3      Provincial            1             0.0       0     0.000000
# 4      Provincial            1             0.0       0     0.000000
# 11     Provincial            1             0.0       0     0.000000
# 16        Private            1             0.0       0     0.000000
# 32      Municipal            1             0.0       0     0.000000
# ...           ...          ...             ...     ...          ...
# 17440  Provincial            1             0.0       0     0.000000
# 17441     Private           42            40.0       1     0.952381
# 17447     Private            1             0.0       0     0.000000
# 17480  Provincial            1             0.0       0     0.000000
# 17503  Provincial          111             7.0       1     0.063063
#
# [1523 rows x 13 columns]

# %% [markdown]
# ✔️5.Obtener un dataframe que contenga solo los registros cuya provincia contenga el string "San"

# %%
covid.loc[covid['Province'].str.contains('San'),]
# Out:
#       Testing_Date             Province  Province_Code      District  \
# 3       2020-02-25  Santiago del Estero             86  Capital City
# 4       2020-02-27  Santiago del Estero             86  Capital City
# 11      2020-03-08  Santiago del Estero             86  Capital City
# 16      2020-03-11             Santa Fe             82       Rosario
# 32      2020-03-18             Santa Fe             82       Rosario
# ...            ...                  ...            ...           ...
# 17440   2020-08-27             Santa Fe             82       Caseros
# 17441   2020-08-27             Santa Fe             82       Rosario
# 17447   2020-08-27             Santa Fe             82       Caseros
# 17480   2020-08-27  Santiago del Estero             86  Capital City
# 17503   2020-08-27             San Luis             74    La Capital
#
#        District_Code             Locality  Locality_Code Financing  \
# 3                 49  SANTIAGO DEL ESTERO            110    Public
# 4                 49  SANTIAGO DEL ESTERO            110    Public
# 11                49  SANTIAGO DEL ESTERO            110    Public
# 16                84              ROSARIO            270   Private
# 32                84              ROSARIO            270    Public
# ...              ...                  ...            ...       ...
# 17440             14              CASILDA             50    Public
# 17441             84              ROSARIO            270   Private
# 17447             14              CASILDA             50   Private
# 17480             49  SANTIAGO DEL ESTERO            110    Public
# 17503             56             SAN LUIS            150    Public
#
#              Type  Total_Tests  Positive_Cases  Alerta  Positividad
# 3      Provincial            1             0.0       0     0.000000
# 4      Provincial            1             0.0       0     0.000000
# 11     Provincial            1             0.0       0     0.000000
# 16        Private            1             0.0       0     0.000000
# 32      Municipal            1             0.0       0     0.000000
# ...           ...          ...             ...     ...          ...
# 17440  Provincial            1             0.0       0     0.000000
# 17441     Private           42            40.0       1     0.952381
# 17447     Private            1             0.0       0     0.000000
# 17480  Provincial            1             0.0       0     0.000000
# 17503  Provincial          111             7.0       1     0.063063
#
# [1523 rows x 13 columns]

# %% [markdown]
# ✔️6.Obtener un dataframe que contenga solo registros cuyos casos positivos se encuentren entre 10 y 20

# %%
covid[covid['Total_Tests'].between(10,20)]
# Out:
#       Testing_Date      Province  Province_Code          District  \
# 6       2020-02-28          CABA              2         COMUNA 04
# 11      2020-03-06          CABA              2         COMUNA 04
# 15      2020-03-09          CABA              2         COMUNA 04
# 65      2020-03-22       Neuquén             58       Confluencia
# 79      2020-03-23         Chaco             22      San Fernando
# ...            ...           ...            ...               ...
# 17490   2020-08-27       Neuquén             58       Confluencia
# 17496   2020-08-27  Buenos Aires              6  Florencio Varela
# 17502   2020-08-27  Buenos Aires              6       Berazategui
# 17512   2020-08-27      La Pampa             42      Capital City
# 17514   2020-08-27         Jujuy             38         El Carmen
#
#        District_Code          Locality  Locality_Code Financing        Type  \
# 6                  4  PARQUE PATRICIOS             10    Public    National
# 11                 4  PARQUE PATRICIOS             10    Public    National
# 15                 4  PARQUE PATRICIOS             10    Public    National
# 65                35           NEUQUEN             70    Public  Provincial
# 79               140       RESISTENCIA             60    Public  Provincial
# ...              ...               ...            ...       ...         ...
# 17490             35           NEUQUEN             70    Public  Provincial
# 17496            274  FLORENCIO VARELA             10   Private     Private
# 17502             91       BERAZATEGUI             10    Public  Provincial
# 17512             21        SANTA ROSA             20    Public  Provincial
# 17514             14            PERICO             90    Public  Provincial
#
#        Total_Tests  Positive_Cases
# 6               10             0.0
# 11              11             7.0
# 15              13             7.0
# 65              10             2.0
# 79              12             0.0
# ...            ...             ...
# 17490           15            15.0
# 17496           12             4.0
# 17502           16             4.0
# 17512           10             0.0
# 17514           18            12.0
#
# [2382 rows x 11 columns]

# %% [markdown]
# ✔️7.Obtener SOLO el registro que contenga la mayor cantidad de casos positivos, posteriormente hacer un print de estos casos (sin copiar el dato a mano)

# %%
maximo = covid.sort_values('Positive_Cases').tail(1)

# %%
list(maximo.loc[:,'Positive_Cases'])[0]
# Out:
# nan

# %%
maximo.loc[:,'Positive_Cases'].values[0]
# Out:
# nan

# %%
registro_mayor= covid[covid['Positive_Cases'] == covid['Positive_Cases'].max()]

# %%
# Solucion

# %%
registro_mayor
# Out:
#       Testing_Date Province  Province_Code   District  District_Code  \
# 13718   2020-08-07     CABA              2  COMUNA 02              2
#
#        Locality  Locality_Code Financing               Type  Total_Tests  \
# 13718  RECOLETA             10    Public  Public University         1597
#
#        Positive_Cases
# 13718           943.0

# %%
x = registro_mayor['Total_Tests']
# Out:
# 13718    1597
# Name: Total_Tests, dtype: int64

# %% [markdown]
# ✔️8.Cual es el porcentaje de registros que pertenecen a CABA?

# %%
df = covid.loc[:,'Province'].value_counts(normalize = True).to_frame()

# %%
df.columns = ['Porcentaje']
df['Porcentaje'] = df['Porcentaje']* 100

# %%
df2 = df.reset_index()

# %%
df2.columns = ['Province', 'Porcentaje']

# %%
df2.loc[df2['Province'] =='CABA', 'Porcentaje']
# Out:
# 1    25.850457
# Name: Porcentaje, dtype: float64

# %%
list(df2.loc[df2['Province'] =='CABA', 'Porcentaje'])
# Out:
# [25.850456621004565]

# %%
porcentaje_caba = list(df2.loc[df2['Province'] =='CABA', 'Porcentaje'])[0]

# %%
porcentaje_caba
# Out:
# 25.850456621004565

# %% [markdown]
# # GROUP BY

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
valor = [1,9,11,3,2,6,8,4,4,11,2,2,4,3,2,12,8]
color = ['AM','VE','VE','AM','AM','AM','VE','AZ','AM','VE','AM','AZ','AM','AZ','AZ','VE','VE']

# %%
df = pd.DataFrame({
    'color':color,
    'valor':valor
})

# %%
df
# Out:
#    color  valor
# 0     AM      1
# 1     VE      9
# 2     VE     11
# 3     AM      3
# 4     AM      2
# 5     AM      6
# 6     VE      8
# 7     AZ      4
# 8     AM      4
# 9     VE     11
# 10    AM      2
# 11    AZ      2
# 12    AM      4
# 13    AZ      3
# 14    AZ      2
# 15    VE     12
# 16    VE      8

# %%
df.groupby('color')

# %% [markdown]
# 🦠Vemos como agrupó

# %%
#df.groupby('color').groups  devuelve los grupos enm listas

# %%
df.groupby('color', as_index = False).sum()
# Out:
#   color  valor
# 0    AM     22
# 1    AZ     11
# 2    VE     59

# %%
covid.groupby('Province', as_index = False)['Positive_Cases'].sum().sort_values('Positive_Cases', ascending = False)
# Out:
#                Province  Positive_Cases
# 1                  CABA        235696.0
# 0          Buenos Aires        115422.0
# 6               Córdoba          8080.0
# 21             Santa Fe          7221.0
# 9                 Jujuy          6076.0
# 12              Mendoza          5820.0
# 3                 Chaco          5654.0
# 16            Río Negro          5566.0
# 17                Salta          4055.0
# 15              Neuquén          3309.0
# 7            Entre Ríos          2797.0
# 24              Tucumán          1915.0
# 23     Tierra del Fuego          1669.0
# 20           Santa Cruz          1640.0
# 11             La Rioja          1399.0
# 22  Santiago del Estero           723.0
# 4                Chubut           690.0
# 18             San Juan           218.0
# 5            Corrientes           215.0
# 10             La Pampa           196.0
# 8               Formosa           145.0
# 2             Catamarca            80.0
# 19             San Luis            74.0
# 13             Misiones            40.0
# 14        NOT SPECIFIED            29.0

# %%
covid.groupby('Province')['Positive_Cases'].sum().sort_values(ascending=False)
# Out:
# Province
# CABA                   235696.0
# Buenos Aires           115422.0
# Córdoba                  8080.0
# Santa Fe                 7221.0
# Jujuy                    6076.0
# Mendoza                  5820.0
# Chaco                    5654.0
# Río Negro                5566.0
# Salta                    4055.0
# Neuquén                  3309.0
# Entre Ríos               2797.0
# Tucumán                  1915.0
# Tierra del Fuego         1669.0
# Santa Cruz               1640.0
# La Rioja                 1399.0
# Santiago del Estero       723.0
# Chubut                    690.0
# San Juan                  218.0
# Corrientes                215.0
# La Pampa                  196.0
# Formosa                   145.0
# Catamarca                  80.0
# San Luis                   74.0
# Misiones                   40.0
# NOT SPECIFIED              29.0
# Name: Positive_Cases, dtype: float64

# %% [markdown]
# 🦠Agrupar el df de covid por Provincia, realizando una agregacion de suma en la columna de casos positivos, ordenar de forma descendente por numero de casos

# %%
covid.groupby(['Province', 'Financing'], as_index = False)['Positive_Cases'].sum().sort_values('Positive_Cases', ascending = False)
# Out:
#                Province Financing  Positive_Cases
# 3                  CABA    Public        121738.0
# 2                  CABA   Private        113958.0
# 1          Buenos Aires    Public         89521.0
# 0          Buenos Aires   Private         25901.0
# 13              Córdoba    Public          7616.0
# 18                Jujuy    Public          5723.0
# 24              Mendoza    Public          5490.0
# 7                 Chaco    Public          5397.0
# 31            Río Negro    Public          5220.0
# 41             Santa Fe    Public          4153.0
# 40             Santa Fe   Private          3068.0
# 29              Neuquén    Public          2739.0
# 15           Entre Ríos    Public          2720.0
# 32                Salta   Private          2227.0
# 33                Salta    Public          1828.0
# 47              Tucumán    Public          1678.0
# 45     Tierra del Fuego    Public          1659.0
# 22             La Rioja    Public          1392.0
# 39           Santa Cruz    Public          1390.0
# 43  Santiago del Estero    Public           706.0
# 9                Chubut    Public           617.0
# 28              Neuquén   Private           570.0
# 12              Córdoba   Private           464.0
# 17                Jujuy   Private           353.0
# 30            Río Negro   Private           346.0
# 23              Mendoza   Private           330.0
# 6                 Chaco   Private           257.0
# 38           Santa Cruz   Private           250.0
# 46              Tucumán   Private           237.0
# 35             San Juan    Public           218.0
# 11           Corrientes    Public           212.0
# 20             La Pampa    Public           196.0
# 16              Formosa    Public           145.0
# 5             Catamarca    Public            80.0
# 14           Entre Ríos   Private            77.0
# 37             San Luis    Public            74.0
# 8                Chubut   Private            73.0
# 26             Misiones    Public            38.0
# 27        NOT SPECIFIED   Private            29.0
# 42  Santiago del Estero   Private            17.0
# 44     Tierra del Fuego   Private            10.0
# 21             La Rioja   Private             7.0
# 10           Corrientes   Private             3.0
# 25             Misiones   Private             2.0
# 34             San Juan   Private             0.0
# 36             San Luis   Private             0.0
# 4             Catamarca   Private             0.0
# 19             La Pampa   Private             0.0

# %% [markdown]
# 🧼 Que paso?

# %% [markdown]
# 🧼 Agrupar el df de covid por Provincia y por tipo de financiamiento, realizando una agregacion de suma en la columna de casos positivos, ordenar de forma descendente por numero de casos

# %%
#.agg({'Positive_Cases':'sum'}, 'Total_Tests':'min') recibe un diccionario

# %%
covid.groupby(["Province", "Financing"], as_index = False).agg({'Positive_Cases':'sum', 'Total_Tests':'min'}).sort_values("Positive_Cases", ascending = False)
# Out:
#                Province Financing  Positive_Cases  Total_Tests
# 3                  CABA    Public        121738.0            1
# 2                  CABA   Private        113958.0            1
# 1          Buenos Aires    Public         89521.0            1
# 0          Buenos Aires   Private         25901.0            1
# 13              Córdoba    Public          7616.0            1
# 18                Jujuy    Public          5723.0            1
# 24              Mendoza    Public          5490.0            1
# 7                 Chaco    Public          5397.0            1
# 31            Río Negro    Public          5220.0            1
# 41             Santa Fe    Public          4153.0            1
# 40             Santa Fe   Private          3068.0            1
# 29              Neuquén    Public          2739.0            1
# 15           Entre Ríos    Public          2720.0            1
# 32                Salta   Private          2227.0            1
# 33                Salta    Public          1828.0            1
# 47              Tucumán    Public          1678.0            1
# 45     Tierra del Fuego    Public          1659.0            1
# 22             La Rioja    Public          1392.0            1
# 39           Santa Cruz    Public          1390.0            1
# 43  Santiago del Estero    Public           706.0            1
# 9                Chubut    Public           617.0            1
# 28              Neuquén   Private           570.0            1
# 12              Córdoba   Private           464.0            1
# 17                Jujuy   Private           353.0            1
# 30            Río Negro   Private           346.0            1
# 23              Mendoza   Private           330.0            1
# 6                 Chaco   Private           257.0            1
# 38           Santa Cruz   Private           250.0            1
# 46              Tucumán   Private           237.0            1
# 35             San Juan    Public           218.0            1
# 11           Corrientes    Public           212.0            1
# 20             La Pampa    Public           196.0            1
# 16              Formosa    Public           145.0            1
# 5             Catamarca    Public            80.0            1
# 14           Entre Ríos   Private            77.0            1
# 37             San Luis    Public            74.0            1
# 8                Chubut   Private            73.0            1
# 26             Misiones    Public            38.0            1
# 27        NOT SPECIFIED   Private            29.0            1
# 42  Santiago del Estero   Private            17.0            2
# 44     Tierra del Fuego   Private            10.0            1
# 21             La Rioja   Private             7.0            1
# 10           Corrientes   Private             3.0            1
# 25             Misiones   Private             2.0            1
# 34             San Juan   Private             0.0            1
# 36             San Luis   Private             0.0            1
# 4             Catamarca   Private             0.0            1
# 19             La Pampa   Private             0.0            1

# %% [markdown]
# # DATAFRAME ARGENTINA

# %% [markdown]
# 🧉 Abrir el csv argentina.csv

# %%
arg = pd.read_csv(r'C:\Users\conra\Desktop\Python\argentina.csv')
arg
# Out:
#                province           gdp  illiteracy    poverty  deficient_infra  \
# 0          Buenos Aires  2.926899e+08    1.383240   8.167798         5.511856
# 1             Catamarca  6.150949e+06    2.344140   9.234095        10.464484
# 2               Córdoba  6.936374e+07    2.714140   5.382380        10.436086
# 3            Corrientes  7.968013e+06    5.602420  12.747191        17.438858
# 4                 Chaco  9.832643e+06    7.517580  15.862619        31.479527
# 5                Chubut  1.774785e+07    1.548060   8.051752         8.044618
# 6            Entre Ríos  2.074341e+07    3.185580   7.288751        18.794568
# 7               Formosa  3.807057e+06    4.610640  17.035583        28.004985
# 8                 Jujuy  6.484938e+06    2.151390  13.367965        12.483179
# 9              La Pampa  6.990262e+06    1.539300   3.398774        16.505714
# 10             La Rioja  5.590516e+06    2.773210  10.875152         7.403254
# 11              Mendoza  3.343137e+07    2.200200   5.692798         3.839852
# 12             Misiones  9.646826e+06    6.863950  13.529788         8.325740
# 13              Neuquén  2.256411e+07    1.943750   9.456635        11.267278
# 14            Río Negro  1.026458e+07    2.031420   8.678391        14.885444
# 15                Salta  1.343883e+07    3.346090  16.870500        14.182303
# 16             San Juan  8.262309e+06    2.963260   9.050784         3.914390
# 17             San Luis  1.178085e+07    3.433650   6.593771         9.679894
# 18           Santa Cruz  1.166374e+07    0.791485   8.024762         7.411364
# 19             Santa Fe  8.158869e+07    1.975940   6.081012        11.869195
# 20  Santiago del Estero  8.387859e+06    6.272090  11.759000        20.491433
# 21              Tucumán  1.385620e+07    3.770370  11.214239         6.466665
#
#     school_dropout  no_healthcare  birth_mortal       pop  \
# 0         0.766168        48.7947           4.4  15625084
# 1         0.951963        45.0456           1.5    367828
# 2         1.035056        45.7640           4.8   3308876
# 3         3.864265        62.1103           5.9    992595
# 4         2.577462        65.5104           7.5   1055259
# 5         0.586309        39.5473           3.0    509108
# 6         1.887188        48.6571           3.1   1235994
# 7         2.268974        65.8126          16.2    530162
# 8         0.721295        54.1615           3.7    673307
# 9         0.204093        45.4764           7.2    318951
# 10        3.844949        40.8341          11.4    333642
# 11        1.063718        50.5843           4.4   1738929
# 12        3.129124        57.8339           8.1   1101593
# 13        1.393504        48.7431           3.3    551266
# 14        0.408042        49.9463           0.8    638645
# 15        1.482030        60.4230           5.8   1214441
# 16        3.298413        52.9684           4.2    681055
# 17        2.000172        51.6154           3.8    432310
# 18        0.289262        29.2321           3.3    273964
# 19        2.872181        41.9660           2.6   3194537
# 20        2.325598        63.6637           1.7    874006
# 21        0.977285        48.2242           3.0   1448188
#
#     movie_theatres_per_cap  doctors_per_cap
# 0                 0.000006         0.004836
# 1                 0.000005         0.004502
# 2                 0.000011         0.010175
# 3                 0.000004         0.004495
# 4                 0.000003         0.003605
# 5                 0.000016         0.004498
# 6                 0.000006         0.004679
# 7                 0.000004         0.003440
# 8                 0.000003         0.003958
# 9                 0.000019         0.005415
# 10                0.000012         0.005092
# 11                0.000008         0.005720
# 12                0.000002         0.002880
# 13                0.000009         0.005067
# 14                0.000009         0.004898
# 15                0.000004         0.003991
# 16                0.000006         0.005044
# 17                0.000005         0.006102
# 18                0.000011         0.004271
# 19                0.000007         0.006672
# 20                0.000003         0.002821
# 21                0.000005         0.005501

# %% [markdown]
# 🧉 Imprimir los primeros registros

# %%
arg.head()
# Out:
#        province           gdp  illiteracy    poverty  deficient_infra  \
# 0  Buenos Aires  2.926899e+08     1.38324   8.167798         5.511856
# 1     Catamarca  6.150949e+06     2.34414   9.234095        10.464484
# 2       Córdoba  6.936374e+07     2.71414   5.382380        10.436086
# 3    Corrientes  7.968013e+06     5.60242  12.747191        17.438858
# 4         Chaco  9.832643e+06     7.51758  15.862619        31.479527
#
#    school_dropout  no_healthcare  birth_mortal       pop  \
# 0        0.766168        48.7947           4.4  15625084
# 1        0.951963        45.0456           1.5    367828
# 2        1.035056        45.7640           4.8   3308876
# 3        3.864265        62.1103           5.9    992595
# 4        2.577462        65.5104           7.5   1055259
#
#    movie_theatres_per_cap  doctors_per_cap
# 0                0.000006         0.004836
# 1                0.000005         0.004502
# 2                0.000011         0.010175
# 3                0.000004         0.004495
# 4                0.000003         0.003605

# %%
arg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   province                22 non-null     object
#  1   gdp                     22 non-null     float64
#  2   illiteracy              22 non-null     float64
#  3   poverty                 22 non-null     float64
#  4   deficient_infra         22 non-null     float64
#  5   school_dropout          22 non-null     float64
#  6   no_healthcare           22 non-null     float64
#  7   birth_mortal            22 non-null     float64
#  8   pop                     22 non-null     int64
#  9   movie_theatres_per_cap  22 non-null     float64
#  10  doctors_per_cap         22 non-null     float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.0+ KB

# %%
arg.shape
# Out:
# (22, 11)

# %%
arg.describe()
# Out:
#                 gdp  illiteracy    poverty  deficient_infra  school_dropout  \
# count  2.200000e+01   22.000000  22.000000        22.000000       22.000000
# mean   3.055703e+07    3.225541   9.925625        12.677304        1.724866
# std    6.183100e+07    1.851496   3.779530         7.216860        1.152438
# min    3.807057e+06    0.791485   3.398774         3.839852        0.204093
# 25%    8.041587e+06    1.989810   7.472754         7.569677        0.812617
# 50%    1.096416e+07    2.743675   9.142440        10.865881        1.437767
# 75%    1.999452e+07    3.686190  12.500143        16.100647        2.514496
# max    2.926899e+08    7.517580  17.035583        31.479527        3.864265
#
#        no_healthcare  birth_mortal           pop  movie_theatres_per_cap  \
# count      22.000000     22.000000  2.200000e+01               22.000000
# mean       50.768836      4.986364  1.686352e+06                0.000007
# std         9.181037      3.498339  3.219828e+06                0.000004
# min        29.232100      0.800000  2.739640e+05                0.000002
# 25%        45.548300      3.025000  5.143715e+05                0.000004
# 50%        49.370500      4.000000  7.775305e+05                0.000006
# 75%        56.915800      5.875000  1.230606e+06                0.000009
# max        65.812600     16.200000  1.562508e+07                0.000019
#
#        doctors_per_cap
# count        22.000000
# mean          0.004894
# std           0.001522
# min           0.002821
# 25%           0.004061
# 50%           0.004757
# 75%           0.005334
# max           0.010175

# %% [markdown]
# # MERGE

# %% [markdown]
# 🧉 Queremos agregar al dataframe que tiene datos socio economico de argentina la informacion de la cantidad total de positivos covid de dicha provincia

# %%
covid.groupby('Province', as_index= False)['Positive_Cases'].sum()
# Out:
#                Province  Positive_Cases
# 0          Buenos Aires        115422.0
# 1                  CABA        235696.0
# 2             Catamarca            80.0
# 3                 Chaco          5654.0
# 4                Chubut           690.0
# 5            Corrientes           215.0
# 6               Córdoba          8080.0
# 7            Entre Ríos          2797.0
# 8               Formosa           145.0
# 9                 Jujuy          6076.0
# 10             La Pampa           196.0
# 11             La Rioja          1399.0
# 12              Mendoza          5820.0
# 13             Misiones            40.0
# 14        NOT SPECIFIED            29.0
# 15              Neuquén          3309.0
# 16            Río Negro          5566.0
# 17                Salta          4055.0
# 18             San Juan           218.0
# 19             San Luis            74.0
# 20           Santa Cruz          1640.0
# 21             Santa Fe          7221.0
# 22  Santiago del Estero           723.0
# 23     Tierra del Fuego          1669.0
# 24              Tucumán          1915.0

# %% [markdown]
# 🧉 Realizar un LEFT JOIN, donde se une la tabla de datos socioeconomicos (izquierda) y la de covid (derecha), utilizando como clave el nombre de las provincias

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧉 Para hacer esto tenemos que estar seguros que las provincias se escriban exactamente de igual forma en ambas tablas

# %%
#You are looking for the symmetric difference; all elements that appear only in set a or in set b, but not both:

# %% [markdown]
# 🧉 Vemos que en covid hay 3 mas: CABA (que en el otro dataset unifica caba y bs as), NOT SPECIFIED Y Tierra del Fuergo

# %% [markdown]
# 🧉 Hay que combinar los registros de Buenos Aires y CABA en el dataset de covid

# %% [markdown]
# ⚡ ⚡ ⚡ ⚡ **Bonus Track** ⚡ ⚡ ⚡ ⚡

# %% [markdown]
# 🧉 1.Analizá a groso modo la siguiente hipotesis:
#
# 🧉 2.Hay una correlacion entre la poblacion de una provincia y la cantidad de casos positivos
#
# 🧉 3.Hay una correlacion entre el PBI per capita de una provincia y la cantidad de casos positivos per capita
#
# 🧉 4.Hay una correlacion entre el PBI per capita de una pronvincia y su infraestructura
#
# 🧉 5.Hay una correlacion entre la cantidad de cines per capita y la pobreza de un provincia
#
# 🧉 6.Hay una correlacion entre la cantidad de doctores per capita que hay en una provincia y los casos positivos per capita existen.

# %% [markdown]
# 🧉 1.Hay una correlacion entre la poblacion de una provincia y la cantidad de casos positivos

# %% [markdown]
# **Pearson: relacion lineal**
#
# **Spearman: relacion monotona**
#
# ⚡Si las variables se relacionan de forma no monotona ningun coeficiente de estos puede captar dicha relacion por lo cual:
#
# ⚡ **Un coeficiente de correlación bajo no necesariamente implica que las variables sean independendientes.**
#
# ⚡En una relación monótona, las variables tienden a moverse en la misma dirección relativa, pero no necesariamente a un ritmo constante. En una relación lineal, las variables se mueven en la misma dirección a un ritmo constante.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
